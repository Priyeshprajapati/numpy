# %%
import openpyxl
import numpy as np
wb_obj=openpyxl.load_workbook("P:\\excel\\SALARY_CHART1.xlsx")
sheet_obj=wb_obj.active
cell_obj=sheet_obj.cell(row=1,column=1)
#print(cell_obj)
#print(cell_obj.value)
#print(sheet_obj.max_row,sheet_obj.max_column)
max_column=sheet_obj.max_column
max_row=sheet_obj.max_row
l=[]
#for i in range(1,max_row+1):
#    for j in range(1,max_column):
#        cell_obj=sheet_obj.cell(row=i,column=j)
#        l.append(cell_obj.value)
#arr=np.array(l)
#print(arr)
for i in range(1,max_row+1):
    cell_obj=sheet_obj.cell(row=i,column=2)
    l.append(cell_obj.value)
arr=np.array(l)
#print(arr)
l1=[]
for i in range(1,max_row+1):
    cell_obj=sheet_obj.cell(row=i,column=3)
    l1.append(cell_obj.value)
arr1=np.array(l1)
#print(arr1)    
e=np.array([arr,arr1])
var=e.flatten() 
print("flatten:-",var)
c= np.hstack((arr,arr1))
print("hstask:-",c)
d= np.vstack((arr,arr1))
print("vstack:-",d)
# Out:
# flatten:- ['EMP NAMAE' 'AKSHAY' 'SHYAM' 'MONU' 'YADAV' 'SHANKAR' 'JIVA' 'MAYANK'
#  'AMAN' 'RAJU' 'SIKANDAR' None 'DESIGNATION' 'MANAGER' 'OFFICER' 'CLERK'
#  'WORKER' 'WORKER' 'OFFICER' 'MANAGER' 'WORKER' 'WORKER' 'WORKER' None]
# hstask:- ['EMP NAMAE' 'AKSHAY' 'SHYAM' 'MONU' 'YADAV' 'SHANKAR' 'JIVA' 'MAYANK'
#  'AMAN' 'RAJU' 'SIKANDAR' None 'DESIGNATION' 'MANAGER' 'OFFICER' 'CLERK'
#  'WORKER' 'WORKER' 'OFFICER' 'MANAGER' 'WORKER' 'WORKER' 'WORKER' None]
# vstack:- [['EMP NAMAE' 'AKSHAY' 'SHYAM' 'MONU' 'YADAV' 'SHANKAR' 'JIVA' 'MAYANK'
#   'AMAN' 'RAJU' 'SIKANDAR' None]
#  ['DESIGNATION' 'MANAGER' 'OFFICER' 'CLERK' 'WORKER' 'WORKER' 'OFFICER'
#   'MANAGER' 'WORKER' 'WORKER' 'WORKER' None]]

# %%
import openpyxl    
my_wb = openpyxl.Workbook()    
my_sheet = my_wb.active    
my_sheet_title = my_sheet.title    
print("My sheet title: " + my_sheet_title)
# Out:
# My sheet title: Sheet

# %%
import openpyxl
import numpy as np
wb_obj=openpyxl.load_workbook("P:\\excel\\MARKSHEET.xlsx")
sheet_obj=wb_obj.active
cell_obj=sheet_obj.cell(row=1,column=1)
max_column=sheet_obj.max_column
max_row=sheet_obj.max_row
wb_obj1=openpyxl.load_workbook("P:\\excel\\SALARY_CHART1.xlsx")
sheet_obj1=wb_obj1.active
cell_obj1=sheet_obj1.cell(row=1,column=1)
max_column1=sheet_obj1.max_column
max_row1=sheet_obj1.max_row
l=[]
l1=[]
for i in range(1,max_row+1):
    for j in range(1,max_column+1):
        ar=sheet_obj.cell(row=i,column=j)
        l.append(ar.value)
arr=np.array(l)
for i in range(1,max_row1+1):
    for j in range(1,max_column1+1):
        ar1=sheet_obj1.cell(row=i,column=j)
        l1.append(ar1.value)
arr1=np.array(l1)
print(arr)
print(arr1)
e=np.array([arr,arr1])
var=e.flatten() 
print("flatten:-",var)
c= np.hstack((arr,arr1))
print("hstask:-",c)
kl= np.vstack((arr,arr1))
print("vstack:-",kl)
# Out:
# ['MARKSHEET' None None None None None None None None None None None None
#  None None None None None None None None None None None None None None
#  None None None None None 'S.N' 'STUDENT' 'HINDI' 'ENGLISH' 'MATH'
#  'SCIENCE' 'ARTS' 'GK' 'SOCIAL SCIENCE' 'TOTAL ' 'PERCENT' 'DIVISION'
#  'SUPPLY' 'RESULT' 'MAX' 'MIN' 1 'SHYAM' 75 54 65 95 62 34 60
#  '=SUM(C4:I4)' '=J4/700*100'
#  '=IF(K4>70,"A+",IF(K4>60,"A",IF(K4>50,"B",IF(K4>40,"C","D"))))'
#  '=IF(COUNTIF(C4:I4,">33")=7,"PASS",IF(COUNTIF(C4:I4,">33")=6,"SUPPLY",IF(COUNTIF(C4:I4,">33")=5,"SUPPLY","FAIL")))'
#  '=IF(K4>50,"PASS","FAIL")' '=MAX(C4:I4)' '=MIN(C4:I4)' 2 'RAM' 65 62 52
#  20 52 63 62 '=SUM(C5:I5)' '=J5/700*100'
#  '=IF(K5>70,"A+",IF(K5>60,"A",IF(K5>50,"B",IF(K5>40,"C","D"))))'
#  '=IF(COUNTIF(C5:I5,">33")=7,"PASS",IF(COUNTIF(C5:I5,">33")=6,"SUPPLY",IF(COUNTIF(C5:I5,">33")=5,"SUPPLY","FAIL")))'
#  '=IF(K5>50,"PASS","FAIL")' '=MAX(C5:I5)' '=MIN(C5:I5)' 3 'CHINNTU' 62 32
#  20 35 52 52 63 '=SUM(C6:I6)' '=J6/700*100'
# ...
