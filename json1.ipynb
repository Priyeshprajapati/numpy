# %%
import json
j = '[{"a":"1", "b":"2", "c":"3", "d":"4"}]'
a = json.loads(j)
for i in range(len(a)):
    for j in a[i]:
        print(j,":",a[i][j])
# Out:
# a : 1
# b : 2
# c : 3
# d : 4

# %%
import json
f = open('P:\\excel\\pk.json')
a = json.load(f)
for i in a['result']:
    for j in i:
        print(j,":",i[j])
# Out:
# id : 1
# UserName : kamal
# DOB : 0000-00-00 00:00:00.000
# emailid : ravishankargupta@gmail.com
# password :
# MobileNo :
# UserTypeId : 0
# Nationality :
# Gender : 0
# RoomPreferance :
# AdharNo :
# MaritalStatus : 0
# StatusId : 1
# CreateId : 1
# CreateDate : 2021-01-09 11:41:33.000
# UpdateId : 2
# UpdateDate : 2021-01-09 11:41:33.000
# id : 2
# UserName : kamal
# DOB : 0000-00-00 00:00:00.000
# emailid : ravishankargupta@gmail.com
# password :
# MobileNo :
# UserTypeId : 0
# Nationality :
# Gender : 0
# RoomPreferance :
# AdharNo :
# MaritalStatus : 0
# StatusId : 1
# CreateId : 1
# CreateDate : 2021-01-09 11:42:49.000
# UpdateId : 2
# UpdateDate : 2021-01-09 11:42:49.000
# id : 3
# UserName : kamal
# DOB : 0000-00-00 00:00:00.000
# emailid : ravishankargupta@gmail.com
# password : 12345
# MobileNo :
# UserTypeId : 0
# Nationality :
# Gender : 0
# RoomPreferance :
# AdharNo :
# MaritalStatus : 0
# StatusId : 1
# CreateId : 1
# CreateDate : 2021-01-09 11:44:27.000
# ...

# %%
import json
f = open('P:\\excel\\pk.json')
a = json.load(f)
for i in a['result']:
    print(i["id"],i["UserName"],i["DOB"],i["emailid"],i["password"],i["MobileNo"],i["UserTypeId"],i["Nationality"],i["Gender"],i["RoomPreferance"],i["AdharNo"],i["MaritalStatus"],i["StatusId"],i["CreateId"],i["CreateDate"],i["UpdateId"],i["UpdateDate"])
# Out:
# 1 kamal 0000-00-00 00:00:00.000 ravishankargupta@gmail.com   0  0   0 1 1 2021-01-09 11:41:33.000 2 2021-01-09 11:41:33.000
# 2 kamal 0000-00-00 00:00:00.000 ravishankargupta@gmail.com   0  0   0 1 1 2021-01-09 11:42:49.000 2 2021-01-09 11:42:49.000
# 3 kamal 0000-00-00 00:00:00.000 ravishankargupta@gmail.com 12345  0  0   0 1 1 2021-01-09 11:44:27.000 2 2021-01-09 11:44:27.000
# 4 kamal 0000-00-00 00:00:00.000 ravishankargupta@gmail.com 12345  0  0   0 1 1 2021-01-09 11:46:08.000 2 2021-01-09 11:46:08.000
# 5 kamal 0000-00-00 00:00:00.000 ravishankargupta@gmail.com 123  0  0   0 1 1 2021-01-09 11:49:32.000 2 2021-01-09 11:49:32.000
# 6 kamal 0000-00-00 00:00:00.000 ravishankargupta@gmail.com 123  0  0   0 1 1 2021-01-09 12:01:21.000 2 2021-01-09 12:01:21.000
# 7 kamal 0000-00-00 00:00:00.000 ravishankargupta@gmail.com 123  0  0   0 1 1 2021-01-09 12:01:27.000 2 2021-01-09 12:01:27.000
# 8  0000-00-00 00:00:00.000    0  0   0 1 1 2021-01-09 12:12:58.000 2 2021-01-09 12:12:58.000
# ...

# %%
import csv

f= open("P:\\word\\covid_19_india.csv")
c =csv.reader(f)
c1 = 0
for row in c:
    print(row)
    c1+=1
print("line count",c1)
# Out:
# ['Sno\tDate\tTime\tState/UnionTerritory\tConfirmedIndianNational\tConfirmedForeignNational\tCured\tDeaths\tConfirmed']
# ['1\t30-01-20\t6:00 PM\tKerala\t1\t0\t0\t0\t1']
# ['2\t31-01-20\t6:00 PM\tKerala\t1\t0\t0\t0\t1']
# ['3\t01-02-20\t6:00 PM\tKerala\t2\t0\t0\t0\t2']
# ['4\t02-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['5\t03-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['6\t04-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['7\t05-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['8\t06-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['9\t07-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['10\t08-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['11\t09-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['12\t10-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['13\t11-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['14\t12-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['15\t13-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['16\t14-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ['17\t15-02-20\t6:00 PM\tKerala\t3\t0\t0\t0\t3']
# ...
